# %% [markdown]
# # Práctica 2: Gráfos Aleatorios, Regulares, de Mundo pequeño y libres de escala
#
# ## Estudiar las propiedeades de un grafo aleatorio.

# %%
import networkx as nx

# %%
LC_Aleatorio(n-graph, n, P):
    for i in range(n_graph):
        G = nx.gnp_random_graph(n, p)
        G[i] = nx.average_cluster_index(G)
        if is.connected(G):
            L[i] = nx.average_path_length(G)
        else:
            L[i] = n - 1
    return avg(L), avg(C)

# %%
el segundo apartado, para cada una de las probabilidades debemos hacer una llamada a LC aleatorio y LC_smallword
